# %% [markdown]
# ### Dataset : Rice_Cammeo_Osancik

# %% [markdown]
# #### Import Library

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
rice = pd.read_excel("Rice_Cammeo_Osmancik.xlsx")
rice
# Out:
#        Area   Perimeter  Major_Axis_Length  Minor_Axis_Length  Eccentricity  \
# 0     15231  525.578979         229.749878          85.093788      0.928882
# 1     14656  494.311005         206.020065          91.730972      0.895405
# 2     14634  501.122009         214.106781          87.768288      0.912118
# 3     13176  458.342987         193.337387          87.448395      0.891861
# 4     14688  507.166992         211.743378          89.312454      0.906691
# ...     ...         ...                ...                ...           ...
# 3805  11441  415.858002         170.486771          85.756592      0.864280
# 3806  11625  421.390015         167.714798          89.462570      0.845850
# 3807  12437  442.498993         183.572922          86.801979      0.881144
# 3808   9882  392.296997         161.193985          78.210480      0.874406
# 3809  11434  404.709991         161.079269          90.868195      0.825692
#
#       Convex_Area    Extent     Class
# ...

# %%
rice.shape
# Out:
# (3810, 8)

# %%
rice.isnull().sum()
# Out:
# Area                 0
# Perimeter            0
# Major_Axis_Length    0
# Minor_Axis_Length    0
# Eccentricity         0
# Convex_Area          0
# Extent               0
# Class                0
# dtype: int64

# %%
rice.dtypes
# Out:
# Area                   int64
# Perimeter            float64
# Major_Axis_Length    float64
# Minor_Axis_Length    float64
# Eccentricity         float64
# Convex_Area            int64
# Extent               float64
# Class                 object
# dtype: object

# %%
pd.set_option('display.max_columns', None)

# %%
rice.dtypes
# Out:
# Area                   int64
# Perimeter            float64
# Major_Axis_Length    float64
# Minor_Axis_Length    float64
# Eccentricity         float64
# Convex_Area            int64
# Extent               float64
# Class                 object
# dtype: object

# %%
# Input data
x = rice.drop('Class', axis=1)

# Output data
y = rice['Class']

# %%
x
# Out:
#        Area   Perimeter  Major_Axis_Length  Minor_Axis_Length  Eccentricity  \
# 0     15231  525.578979         229.749878          85.093788      0.928882
# 1     14656  494.311005         206.020065          91.730972      0.895405
# 2     14634  501.122009         214.106781          87.768288      0.912118
# 3     13176  458.342987         193.337387          87.448395      0.891861
# 4     14688  507.166992         211.743378          89.312454      0.906691
# ...     ...         ...                ...                ...           ...
# 3805  11441  415.858002         170.486771          85.756592      0.864280
# 3806  11625  421.390015         167.714798          89.462570      0.845850
# 3807  12437  442.498993         183.572922          86.801979      0.881144
# 3808   9882  392.296997         161.193985          78.210480      0.874406
# 3809  11434  404.709991         161.079269          90.868195      0.825692
#
#       Convex_Area    Extent
# ...

# %%
y
# Out:
# 0         Cammeo
# 1         Cammeo
# 2         Cammeo
# 3         Cammeo
# 4         Cammeo
#           ...
# 3805    Osmancik
# 3806    Osmancik
# 3807    Osmancik
# 3808    Osmancik
# 3809    Osmancik
# Name: Class, Length: 3810, dtype: object

# %%
y.value_counts()
# Out:
# Class
# Osmancik    2180
# Cammeo      1630
# Name: count, dtype: int64

# %%
sns.jointplot(x='Area', y='Eccentricity', data=rice, hue='Class')

# %%
one = rice.iloc[:,0:4]
one['Class'] = y 

two = rice.iloc[:,4:7]
two['Class'] = y

# %%
sns.pairplot(one, hue='Class')

# %%
sns.pairplot(two, hue='Class')

# %%
sns.boxplot(data=x)
# Out:
# <Axes: >

# %%
rice.describe
# Out:
# <bound method NDFrame.describe of        Area   Perimeter  Major_Axis_Length  Minor_Axis_Length  Eccentricity  \
# 0     15231  525.578979         229.749878          85.093788      0.928882
# 1     14656  494.311005         206.020065          91.730972      0.895405
# 2     14634  501.122009         214.106781          87.768288      0.912118
# 3     13176  458.342987         193.337387          87.448395      0.891861
# 4     14688  507.166992         211.743378          89.312454      0.906691
# ...     ...         ...                ...                ...           ...
# 3805  11441  415.858002         170.486771          85.756592      0.864280
# 3806  11625  421.390015         167.714798          89.462570      0.845850
# 3807  12437  442.498993         183.572922          86.801979      0.881144
# 3808   9882  392.296997         161.193985          78.210480      0.874406
# 3809  11434  404.709991         161.079269          90.868195      0.825692
#
# ...

# %%
rice.max()
# Out:
# Area                      18913
# Perimeter            548.445984
# Major_Axis_Length    239.010498
# Minor_Axis_Length     107.54245
# Eccentricity           0.948007
# Convex_Area               19099
# Extent                  0.86105
# Class                  Osmancik
# dtype: object

# %%
plt.figure(figsize=(16,9))
sns.boxplot(data=x.drop(['Area', 'Convex_Area'], axis=1))
# Out:
# <Axes: >

# %% [markdown]
# #### Outlier Detection and Removal

# %%
from sklearn.ensemble import IsolationForest

# %%
iso = IsolationForest(contamination=0.05, random_state=0)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
clean = iso.fit_predict(x,y)

# %%
clean
# Out:
# array([-1,  1,  1, ...,  1,  1,  1])

# %%
x_clean = x[clean==1]
y_clean = y[clean==1]

# %%
x_clean.shape
# Out:
# (3619, 7)

# %%
y_clean.shape
# Out:
# (3619,)

# %% [markdown]
# #### Data Balancing / Resampling

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
ros = RandomOverSampler(random_state=0)

# %%
x_res, y_res  = ros.fit_resample(x_clean, y_clean)

# %%
x_res.shape
# Out:
# (4180, 7)

# %%
sns.countplot(x = y_res)
# Out:
# <Axes: xlabel='Class', ylabel='count'>

# %%
y_res.value_counts()
# Out:
# Class
# Cammeo      2090
# Osmancik    2090
# Name: count, dtype: int64

# %% [markdown]
# #### Feature Selection

# %%
from sklearn.feature_selection import SelectKBest, chi2

# %%
skf = SelectKBest(k=5, score_func=chi2)

# %%
skf.fit(x_res,y_res)
# Out:
# SelectKBest(k=5, score_func=<function chi2 at 0x7118331519e0>)

# %%
skf.get_support()
# Out:
# array([ True,  True,  True,  True, False,  True, False])

# %%
x = x_res.iloc[:,skf.get_support()]    
x
# Out:
#        Area   Perimeter  Major_Axis_Length  Minor_Axis_Length  Convex_Area
# 0     14656  494.311005         206.020065          91.730972        15072
# 1     14634  501.122009         214.106781          87.768288        14954
# 2     13176  458.342987         193.337387          87.448395        13368
# 3     14688  507.166992         211.743378          89.312454        15262
# 4     13479  477.015991         200.053055          86.650291        13786
# ...     ...         ...                ...                ...          ...
# 4175  14828  493.500000         209.903564          90.669914        15090
# 4176  14439  492.553009         211.852142          87.434669        14614
# 4177  15600  502.842987         205.275513          99.052811        16130
# 4178  11999  465.657990         194.784256          80.438240        12364
# 4179  14999  498.540985         213.508026          90.109741        15295
#
# [4180 rows x 5 columns]

# %% [markdown]
# #### Feature Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
x_scaled = scaler.fit_transform(x)

# %%
pd.DataFrame(x_scaled).describe()
# Out:
#                  0            1            2            3            4
# count  4180.000000  4180.000000  4180.000000  4180.000000  4180.000000
# mean      0.480432     0.503860     0.490049     0.524565     0.484902
# std       0.218982     0.229196     0.229791     0.167424     0.221353
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.304726     0.310065     0.286606     0.411799     0.308117
# 50%       0.459411     0.489189     0.493497     0.527129     0.461549
# 75%       0.660017     0.699352     0.687228     0.643579     0.665110
# max       1.000000     1.000000     1.000000     1.000000     1.000000

# %% [markdown]
# #### Cross Validation

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(
x_scaled, y_res, random_state=0, stratify=y_res)

# %%
x_train.shape
# Out:
# (3135, 5)

# %%
x_test.shape
# Out:
# (1045, 5)

# %% [markdown]
# #### Hyperparameter Tuning

# %%
params = {
    
    'criterion': ["gini", "entropy", "log_loss"],
    'splitter' : ["best", "random"],
    'random_state': [0,1,2,3,4]
}

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier

# %%
grid = GridSearchCV(DecisionTreeClassifier(), param_grid=params, cv=5)

# %%
grid.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'random_state': [0, 1, 2, 3, 4],
#                          'splitter': ['best', 'random']})

# %%
grid.best_estimator_
# Out:
# DecisionTreeClassifier(random_state=1, splitter='random')

# %% [markdown]
# #### Build the model

# %%
DTC =  grid.best_estimator_

# %%
from sklearn.metrics import classification_report, accuracy_score
from sklearn.metrics import ConfusionMatrixDisplay

# %%
DTC_pred = DTC.predict(x_test)

# %%
ConfusionMatrixDisplay.from_predictions(y_test, DTC_pred)

# %%
accuracy_score(y_test, DTC_pred)
# Out:
# 0.9138755980861244

# %%
print(classification_report(y_test, DTC_pred))
# Out:
#               precision    recall  f1-score   support
#
#       Cammeo       0.88      0.96      0.92       523
#     Osmancik       0.96      0.87      0.91       522
#
#     accuracy                           0.91      1045
#    macro avg       0.92      0.91      0.91      1045
# weighted avg       0.92      0.91      0.91      1045

# %% [markdown]
# #### Hyperparameter tuninng for KNN

# %%
params = {
    'n_neighbors': [5,7,8,10,12,13,15,18,20],
    'weights': ['uniform', 'distance'],
    'algorithm': ['auto','kd_tree', 'ball_tree', 'brute']
}

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
grid = GridSearchCV(estimator=KNeighborsClassifier(),
                   param_grid=params,
                   scoring='accuracy',
                   cv=5)

# %%
grid.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(),
#              param_grid={'algorithm': ['auto', 'kd_tree', 'ball_tree', 'brute'],
#                          'n_neighbors': [5, 7, 8, 10, 12, 13, 15, 18, 20],
#                          'weights': ['uniform', 'distance']},
#              scoring='accuracy')

# %%
grid.best_estimator_
# Out:
# KNeighborsClassifier(n_neighbors=18, weights='distance')

# %%
knn = grid.best_estimator_

# %%
knn_pred = knn.predict(x_test)

# %%
ConfusionMatrixDisplay.from_predictions(y_test, knn_pred)

# %%
accuracy_score(y_test, knn_pred)
# Out:
# 0.9406698564593301

# %% [markdown]
# #### Hyperparameter tuninng for Random Forest Calssifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
param_rf = {
    'n_estimators' : [5,10,15,20,25,30,50],
    'random_state': [0,1,2,3,4,5],
}

# %%
grid = GridSearchCV(estimator = RandomForestClassifier(),
                   param_grid=param_rf,
                   scoring='accuracy',
                   cv=5)

# %%
grid.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'n_estimators': [5, 10, 15, 20, 25, 30, 50],
#                          'random_state': [0, 1, 2, 3, 4, 5]},
#              scoring='accuracy')

# %%
grid.best_estimator_
# Out:
# RandomForestClassifier(n_estimators=50, random_state=3)

# %%
rf = grid.best_estimator_

# %%
rf_pred = rf.predict(x_test)

# %%
ConfusionMatrixDisplay.from_predictions(y_test, rf_pred)

# %%
accuracy_score(y_test, rf_pred)
# Out:
# 0.938755980861244

# %% [markdown]
# #### Hyperparameter tuninng for SVM Algorithm

# %%
from sklearn.svm import SVC

# %%
param_svm = {
    'kernel': ['rbf', 'linear', 'poly', 'sigmoid']
}

# %%
grid = GridSearchCV(estimator = SVC(),
                   param_grid=param_svm,
                   scoring='accuracy',
                   cv=5)

# %%
grid.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'kernel': ['rbf', 'linear', 'poly', 'sigmoid']},
#              scoring='accuracy')

# %%
grid.best_estimator_
# Out:
# SVC(kernel='poly')

# %%
sv = grid.best_estimator_

# %%
sv_pred = sv.predict(x_test)

# %%
ConfusionMatrixDisplay.from_predictions(y_test, sv_pred)

# %%
accuracy_score(y_test, sv_pred)
# Out:
# 0.9244019138755981

# %% [markdown]
# #### Hyperparameter tuninng for Gaussian Naive Classifier

# %%
from sklearn.naive_bayes import GaussianNB

# %%
classifier = GaussianNB()

# %%
classifier.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
GNB_pred = classifier.predict(x_test)

# %%
ConfusionMatrixDisplay.from_predictions(y_test, GNB_pred)

# %%
accuracy_score(y_test, GNB_pred)
# Out:
# 0.8947368421052632

# %% [markdown]
# #### Hyperparameter tunning for Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
param_LR = {
    'penalty':['l1','l2'],
    'C':[1.0, 1.5, 2.0, 2.0],
    'fit_intercept':[True, False], 
    'solver':['lbfgs']
}

# %%
grid = GridSearchCV(estimator = LogisticRegression(),
                   param_grid=param_LR,
                   scoring='accuracy',
                   cv=5)

# %%
grid.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=LogisticRegression(),
#              param_grid={'C': [1.0, 1.5, 2.0, 2.0],
#                          'fit_intercept': [True, False],
#                          'penalty': ['l1', 'l2'], 'solver': ['lbfgs']},
#              scoring='accuracy')

# %%
grid.best_estimator_
# Out:
# LogisticRegression(C=1.5)

# %%
LR = grid.best_estimator_

# %%
LR_pred = LR.predict(x_test)

# %%
ConfusionMatrixDisplay.from_predictions(y_test, LR_pred)

# %%
accuracy_score(y_test, LR_pred)
# Out:
# 0.9215311004784689

# %% [markdown]
# #### Hyperparameter tunning for Artificial Neural Network

# %%
from sklearn.neural_network import MLPClassifier

# %%
param_MLP = {
    'activation':['relu'],
    'max_iter':[500],
    'random_state':[0], 
    'hidden_layer_sizes':[500,500,500,500]
}

# %%
grid = GridSearchCV(estimator = MLPClassifier(),
                   param_grid=param_MLP,
                   scoring='accuracy',
                   cv=5)

# %%
grid.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=MLPClassifier(),
#              param_grid={'activation': ['relu'],
#                          'hidden_layer_sizes': [500, 500, 500, 500],
#                          'max_iter': [500], 'random_state': [0]},
#              scoring='accuracy')

# %%
MLP = grid.best_estimator_

# %%
MLP_pred = MLP.predict(x_test)

# %%
ConfusionMatrixDisplay.from_predictions(y_test, MLP_pred)

# %%
accuracy_score(y_test, MLP_pred)
# Out:
# 0.9224880382775119

# %%
print('Accuracy Score of DecisionTree Classifier:', accuracy_score(y_test, DTC_pred))
print('Accuracy Score of K Neighbors Classifier:', accuracy_score(y_test, knn_pred))
print('Accuracy Score of Random Forest Classifier:',accuracy_score(y_test, rf_pred))
print('Accuracy Score of SVM-POLY:', accuracy_score(y_test, sv_pred))
print('Accuracy Score of Gaussian Naive Classifier:', accuracy_score(y_test, GNB_pred))
print('Accuracy Score of Logistic Regression:', accuracy_score(y_test, LR_pred))
print('Accuracy Score of ANN-MLP:', accuracy_score(y_test, MLP_pred))
# Out:
# Accuracy Score of DecisionTree Classifier: 0.9138755980861244
# Accuracy Score of K Neighbors Classifier: 0.9406698564593301
# Accuracy Score of Random Forest Classifier: 0.938755980861244
# Accuracy Score of SVM-POLY: 0.9244019138755981
# Accuracy Score of Gaussian Naive Classifier: 0.8947368421052632
# Accuracy Score of Logistic Regression: 0.9215311004784689
# Accuracy Score of ANN-MLP: 0.9224880382775119

# %% [markdown]
# #### Save the model object

# %%
import joblib

# %%
# serialize the ML object

joblib.dump(classifier, 'classifier.model')    #what to dump: clf; where to dump: classifier,model
# Out:
# ['classifier.model']

# %%
# seralize the scaler object

joblib.dump(scaler, 'scaler.model')
# Out:
# ['scaler.model']

# %% [markdown]
# #### GUI

# %%
from tkinter import *

# %%
import tkinter.messagebox
import numpy as np
import matplotlib.pyplot as plt
import joblib

# %%
import pandas as pd

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
top = Tk()
top.title('RICE CLASS CATEGORIZATION SYSTEM')
top.geometry("1500x1000")
top.resizable(0, 0)

#Deserializatiom
classifier = joblib.load('classifier.model')
scaler = joblib.load('scaler.model')

def check():
    global a, b, c, d, e
    new = np.array([[a.get(), b.get(), c.get(), d.get(), e.get()]])
    new = pd.DataFrame({
        'Area' : [a.get()],
        'Perimeter' : [b.get()],
        'Major_Axis_Length' : [c.get()],
        'Minor_Axis_Length' : [d.get()],
        'Convex_Area' : [e.get()]
    })
    y_pred = classifier.predict(scaler.transform(new))
    if y_pred[0]== 'Cammeo':
        tkinter.messagebox.showinfo('Result', "Cammeo")
    elif y_pred[0] == 'Osmancik':
        tkinter.messagebox.showinfo('Result', "Osmancik")
        
a = DoubleVar()
b = DoubleVar()
c = DoubleVar()
d = DoubleVar()
e = DoubleVar()

Label(top, text="RICE CLASS CATEGORIZATION SYSTEM", 
      font=('Ubuntu', 25)).place(x=120,y=30)
Label(top, text="Area:", font=('courier', 16)).place(x=20,y=100)
Entry(top, textvariable=a, font=('courier', 16)).place(x=280,y=100)
Label(top, text="Perimeter:", font=('courier', 16)).place(x=20,y=150)
Entry(top, textvariable=b, font=('courier', 16)).place(x=280,y=150)
Label(top, text="Major_Axis_Length:", font=('courier', 16)).place(x=20,y=200)
Entry(top, textvariable=c, font=('courier', 16)).place(x=280,y=200)
Label(top, text="Minor_Axis_Length",font=('courier', 16)).place(x=20,y=250)
Entry(top, textvariable=d, font=('courier', 16)).place(x=280,y=250)
Label(top, text="Convex_Area", font=('courier', 16)).place(x=20,y=300)
Entry(top, textvariable=e, font=('courier', 16)).place(x=280,y=300)

Button(top, text="--Check--", 
       font=('courier', 16, 'bold'), command=check).place(x=250,y=400)

top.mainloop()
