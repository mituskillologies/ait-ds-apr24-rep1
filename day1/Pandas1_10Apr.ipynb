# %%
import pandas as pd

# %% [markdown]
# ### Series

# %%
s = pd.Series([12,23,34,45,56.0])

# %%
s
# Out:
# 0    12.0
# 1    23.0
# 2    34.0
# 3    45.0
# 4    56.0
# dtype: float64

# %%
s[2] = 50

# %%
s
# Out:
# 0    12.0
# 1    23.0
# 2    50.0
# 3    45.0
# 4    56.0
# dtype: float64

# %%
s.dtype
# Out:
# dtype('float64')

# %%
s = pd.Series([12,23,34,45,56,67,76], index= range(101,108))

# %%
s
# Out:
# 101    12
# 102    23
# 103    34
# 104    45
# 105    56
# 106    67
# 107    76
# dtype: int64

# %% [markdown]
# #### DataFrame

# %%
roll = [1,2,3,4,5]
name = ['Ajinkya', 'Riya', 'Ravi', 'Prashant', 'Sneha']
marks = [67.71, 81.32, 83.12, 73.56, 68.10]

# %%
df = pd.DataFrame({
    'roll': roll,
    'name': name,
    'marks': marks
})

# %%
df
# Out:
#    roll      name  marks
# 0     1   Ajinkya  67.71
# 1     2      Riya  81.32
# 2     3      Ravi  83.12
# 3     4  Prashant  73.56
# 4     5     Sneha  68.10

# %%
df.shape
# Out:
# (5, 3)

# %%
df.size
# Out:
# 15

# %%
df.columns
# Out:
# Index(['roll', 'name', 'marks'], dtype='object')

# %%
pwd
# Out:
# '/home/aditya/GUEST_LECTURES/AIT1_10Apr'

# %% [markdown]
# ## download the datasets

# %%
# location: https://mitu.co.in/dataset
# download all datasets starting from student*

# %% [markdown]
# #### Import the dataset

# %%
df1 = pd.read_csv('student.csv')
# from google.colab import files
# files.upload()

# %%
df1
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
headers = ['roll', 'name', 'class', 'marks', 'age']

df2 = pd.read_csv('student1.csv', names = headers)
df2
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df3 = pd.read_csv('student3.tsv',  sep = '\t')

# %%
df3
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df1
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df1.shape
# Out:
# (10, 5)

# %%
df1.columns
# Out:
# Index(['roll', 'name', 'class', 'marks', 'age'], dtype='object')

# %%
df1.dtypes
# Out:
# roll       int64
# name      object
# class     object
# marks    float64
# age        int64
# dtype: object

# %%
df1.values
# Out:
# array([[1, 'anil', 'TE', 56.77, 22],
#        [2, 'amit', 'TE', 59.77, 21],
#        [3, 'aniket', 'BE', 76.88, 19],
#        [4, 'ajinkya', 'TE', 69.66, 20],
#        [5, 'asha', 'TE', 63.28, 20],
#        [6, 'ayesha', 'BE', 49.55, 20],
#        [7, 'amar', 'BE', 65.34, 19],
#        [8, 'amita', 'BE', 68.33, 23],
#        [9, 'amol', 'TE', 56.75, 20],
#        [10, 'anmol', 'BE', 78.66, 21]], dtype=object)

# %%
df1.head()
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20

# %%
df1.head(7)
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19

# %%
df1.tail()
# Out:
#    roll    name class  marks  age
# 5     6  ayesha    BE  49.55   20
# 6     7    amar    BE  65.34   19
# 7     8   amita    BE  68.33   23
# 8     9    amol    TE  56.75   20
# 9    10   anmol    BE  78.66   21

# %%
df1.tail(3)
# Out:
#    roll   name class  marks  age
# 7     8  amita    BE  68.33   23
# 8     9   amol    TE  56.75   20
# 9    10  anmol    BE  78.66   21

# %%
df1
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df1.max()
# Out:
# roll         10
# name     ayesha
# class        TE
# marks     78.66
# age          23
# dtype: object

# %%
df1.sum()
# Out:
# roll                                                    55
# name     anilamitaniketajinkyaashaayeshaamaramitaamolanmol
# class                                 TETEBETETEBEBEBETEBE
# marks                                               644.99
# age                                                    205
# dtype: object

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   roll    10 non-null     int64
#  1   name    10 non-null     object
#  2   class   10 non-null     object
#  3   marks   10 non-null     float64
#  4   age     10 non-null     int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 532.0+ bytes

# %%
df1.describe()
# Out:
#            roll      marks        age
# count  10.00000  10.000000  10.000000
# mean    5.50000  64.499000  20.500000
# std     3.02765   9.207179   1.269296
# min     1.00000  49.550000  19.000000
# 25%     3.25000  57.520000  20.000000
# 50%     5.50000  64.310000  20.000000
# 75%     7.75000  69.327500  21.000000
# max    10.00000  78.660000  23.000000

# %% [markdown]
# ### data slicing

# %%
df1
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df1.iloc[0:4, 0:3]
# Out:
#    roll     name class
# 0     1     anil    TE
# 1     2     amit    TE
# 2     3   aniket    BE
# 3     4  ajinkya    TE

# %%
df1.iloc[3:6, 1:4]
# Out:
#       name class  marks
# 3  ajinkya    TE  69.66
# 4     asha    TE  63.28
# 5   ayesha    BE  49.55

# %%
df1.iloc[5,:]
# Out:
# roll          6
# name     ayesha
# class        BE
# marks     49.55
# age          20
# Name: 5, dtype: object

# %%
df1.iloc[[3,5,7,8], 0:3]
# Out:
#    roll     name class
# 3     4  ajinkya    TE
# 5     6   ayesha    BE
# 7     8    amita    BE
# 8     9     amol    TE

# %%
df1.iloc[[3,5,6], [1,3]]
# Out:
#       name  marks
# 3  ajinkya  69.66
# 5   ayesha  49.55
# 6     amar  65.34

# %%
df1.iloc[5,1]
# Out:
# 'ayesha'

# %%
df1.loc[:, 'marks']
# Out:
# 0    56.77
# 1    59.77
# 2    76.88
# 3    69.66
# 4    63.28
# 5    49.55
# 6    65.34
# 7    68.33
# 8    56.75
# 9    78.66
# Name: marks, dtype: float64

# %%
df1.loc[:, ['name','marks']]
# Out:
#       name  marks
# 0     anil  56.77
# 1     amit  59.77
# 2   aniket  76.88
# 3  ajinkya  69.66
# 4     asha  63.28
# 5   ayesha  49.55
# 6     amar  65.34
# 7    amita  68.33
# 8     amol  56.75
# 9    anmol  78.66

# %%
df1['name']
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5     ayesha
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df1[['name', 'marks']]
# Out:
#       name  marks
# 0     anil  56.77
# 1     amit  59.77
# 2   aniket  76.88
# 3  ajinkya  69.66
# 4     asha  63.28
# 5   ayesha  49.55
# 6     amar  65.34
# 7    amita  68.33
# 8     amol  56.75
# 9    anmol  78.66

# %%
df1
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df1.drop(4)
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df1.drop([4,6,8])
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 5     6   ayesha    BE  49.55   20
# 7     8    amita    BE  68.33   23
# 9    10    anmol    BE  78.66   21

# %%
df1.drop('name', axis = 1)
# Out:
#    roll class  marks  age
# 0     1    TE  56.77   22
# 1     2    TE  59.77   21
# 2     3    BE  76.88   19
# 3     4    TE  69.66   20
# 4     5    TE  63.28   20
# 5     6    BE  49.55   20
# 6     7    BE  65.34   19
# 7     8    BE  68.33   23
# 8     9    TE  56.75   20
# 9    10    BE  78.66   21

# %%
df1.drop(['name', 'class'], axis = 1)
# Out:
#    roll  marks  age
# 0     1  56.77   22
# 1     2  59.77   21
# 2     3  76.88   19
# 3     4  69.66   20
# 4     5  63.28   20
# 5     6  49.55   20
# 6     7  65.34   19
# 7     8  68.33   23
# 8     9  56.75   20
# 9    10  78.66   21

# %%
df1
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
col = {'roll': 'id', 'marks': 'grade'}

# %%
df1.rename(columns= col)
# Out:
#    id     name class  grade  age
# 0   1     anil    TE  56.77   22
# 1   2     amit    TE  59.77   21
# 2   3   aniket    BE  76.88   19
# 3   4  ajinkya    TE  69.66   20
# 4   5     asha    TE  63.28   20
# 5   6   ayesha    BE  49.55   20
# 6   7     amar    BE  65.34   19
# 7   8    amita    BE  68.33   23
# 8   9     amol    TE  56.75   20
# 9  10    anmol    BE  78.66   21

# %%
ind = {2: 'two', 4: 'four', 6: 'six'}

# %%
df1.rename(index= ind)
# Out:
#       roll     name class  marks  age
# 0        1     anil    TE  56.77   22
# 1        2     amit    TE  59.77   21
# two      3   aniket    BE  76.88   19
# 3        4  ajinkya    TE  69.66   20
# four     5     asha    TE  63.28   20
# 5        6   ayesha    BE  49.55   20
# six      7     amar    BE  65.34   19
# 7        8    amita    BE  68.33   23
# 8        9     amol    TE  56.75   20
# 9       10    anmol    BE  78.66   21

# %%
df1
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %% [markdown]
# ### sorting

# %%
df1.sort_values(by = 'class')
# Out:
#    roll     name class  marks  age
# 2     3   aniket    BE  76.88   19
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 9    10    anmol    BE  78.66   21
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 8     9     amol    TE  56.75   20

# %%
df1.sort_values(by = ['class', 'marks'], ascending= False)
# Out:
#    roll     name class  marks  age
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 1     2     amit    TE  59.77   21
# 0     1     anil    TE  56.77   22
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21
# 2     3   aniket    BE  76.88   19
# 7     8    amita    BE  68.33   23
# 6     7     amar    BE  65.34   19
# 5     6   ayesha    BE  49.55   20

# %% [markdown]
# ### methods on Series

# %%
df1['marks'].max()
# Out:
# 78.66

# %%
df1['marks'].mean()
# Out:
# 64.499

# %%
df1['marks'].std()
# Out:
# 9.207178901994535

# %%
df1['name'].str.upper()
# Out:
# 0       ANIL
# 1       AMIT
# 2     ANIKET
# 3    AJINKYA
# 4       ASHA
# 5     AYESHA
# 6       AMAR
# 7      AMITA
# 8       AMOL
# 9      ANMOL
# Name: name, dtype: object

# %%
df1['name'].str.title()
# Out:
# 0       Anil
# 1       Amit
# 2     Aniket
# 3    Ajinkya
# 4       Asha
# 5     Ayesha
# 6       Amar
# 7      Amita
# 8       Amol
# 9      Anmol
# Name: name, dtype: object

# %%
df1['name'].str.startswith('am')
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# 7     True
# 8     True
# 9    False
# Name: name, dtype: bool

# %%
df1['name'].str.strip()
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5     ayesha
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df1.columns.str.strip()
# Out:
# Index(['roll', 'name', 'class', 'marks', 'age'], dtype='object')

# %% [markdown]
# ### Add or modify column

# %%
df1 = pd.read_csv('student.csv')

# %%
df1
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df1['roll'] = df1['roll'] + 100

# %%
df1
# Out:
#    roll     name class  marks  age
# 0   101     anil    TE  56.77   22
# 1   102     amit    TE  59.77   21
# 2   103   aniket    BE  76.88   19
# 3   104  ajinkya    TE  69.66   20
# 4   105     asha    TE  63.28   20
# 5   106   ayesha    BE  49.55   20
# 6   107     amar    BE  65.34   19
# 7   108    amita    BE  68.33   23
# 8   109     amol    TE  56.75   20
# 9   110    anmol    BE  78.66   21

# %%
import numpy as np

# %%
gender = ['m', 'm', 'm', 'm', 'f', 'f', 'm', 'f', 'm', 'm']

# %%
df1['gender'] = gender

# %%
df1
# cgpa => marks/10 + 1.5
# Out:
#    roll     name class  marks  age gender
# 0   101     anil    TE  56.77   22      m
# 1   102     amit    TE  59.77   21      m
# 2   103   aniket    BE  76.88   19      m
# 3   104  ajinkya    TE  69.66   20      m
# 4   105     asha    TE  63.28   20      f
# 5   106   ayesha    BE  49.55   20      f
# 6   107     amar    BE  65.34   19      m
# 7   108    amita    BE  68.33   23      f
# 8   109     amol    TE  56.75   20      m
# 9   110    anmol    BE  78.66   21      m

# %%
df1['cgpa'] = df1['marks'] / 10 + 1.05

# %%
df1
# Out:
#    roll     name class  marks  age gender   cgpa
# 0   101     anil    TE  56.77   22      m  6.727
# 1   102     amit    TE  59.77   21      m  7.027
# 2   103   aniket    BE  76.88   19      m  8.738
# 3   104  ajinkya    TE  69.66   20      m  8.016
# 4   105     asha    TE  63.28   20      f  7.378
# 5   106   ayesha    BE  49.55   20      f  6.005
# 6   107     amar    BE  65.34   19      m  7.584
# 7   108    amita    BE  68.33   23      f  7.883
# 8   109     amol    TE  56.75   20      m  6.725
# 9   110    anmol    BE  78.66   21      m  8.916

# %%
df1['gender'].value_counts()
# Out:
# gender
# m    7
# f    3
# Name: count, dtype: int64

# %%
df1['class'].value_counts()
# Out:
# class
# TE    5
# BE    5
# Name: count, dtype: int64

# %%
df1['gender'].mode()
# Out:
# 0    m
# Name: gender, dtype: object

# %%
df1['class'].mode()[0]
# Out:
# 'BE'

# %% [markdown]
# ### Group by

# %%
gr = df1.groupby('class')

# %%
gr.get_group('TE')
# Out:
#    roll     name class  marks  age gender   cgpa
# 0   101     anil    TE  56.77   22      m  6.727
# 1   102     amit    TE  59.77   21      m  7.027
# 3   104  ajinkya    TE  69.66   20      m  8.016
# 4   105     asha    TE  63.28   20      f  7.378
# 8   109     amol    TE  56.75   20      m  6.725

# %%
gr.groups
# Out:
# {'BE': [2, 5, 6, 7, 9], 'TE': [0, 1, 3, 4, 8]}

# %%
gr['marks'].mean()
# Out:
# class
# BE    67.752
# TE    61.246
# Name: marks, dtype: float64

# %%
df1
# Out:
#    roll     name class  marks  age gender   cgpa
# 0   101     anil    TE  56.77   22      m  6.727
# 1   102     amit    TE  59.77   21      m  7.027
# 2   103   aniket    BE  76.88   19      m  8.738
# 3   104  ajinkya    TE  69.66   20      m  8.016
# 4   105     asha    TE  63.28   20      f  7.378
# 5   106   ayesha    BE  49.55   20      f  6.005
# 6   107     amar    BE  65.34   19      m  7.584
# 7   108    amita    BE  68.33   23      f  7.883
# 8   109     amol    TE  56.75   20      m  6.725
# 9   110    anmol    BE  78.66   21      m  8.916

# %%
df1.drop(['gender', 'cgpa'], axis = 1, inplace = True)

# %%
df1
# Out:
#    roll     name class  marks  age
# 0   101     anil    TE  56.77   22
# 1   102     amit    TE  59.77   21
# 2   103   aniket    BE  76.88   19
# 3   104  ajinkya    TE  69.66   20
# 4   105     asha    TE  63.28   20
# 5   106   ayesha    BE  49.55   20
# 6   107     amar    BE  65.34   19
# 7   108    amita    BE  68.33   23
# 8   109     amol    TE  56.75   20
# 9   110    anmol    BE  78.66   21

# %%
cgpa = df1['marks']/10 + 1.5

newdf = pd.DataFrame({
    'roll': range(101,111),
    'gender': gender,
    'cgpa': cgpa
})

# %%
newdf
# Out:
#    roll gender   cgpa
# 0   101      m  7.177
# 1   102      m  7.477
# 2   103      m  9.188
# 3   104      m  8.466
# 4   105      f  7.828
# 5   106      f  6.455
# 6   107      m  8.034
# 7   108      f  8.333
# 8   109      m  7.175
# 9   110      m  9.366

# %%
df1.columns
# Out:
# Index(['roll', 'name', 'class', 'marks', 'age'], dtype='object')

# %%
newdf.columns
# Out:
# Index(['roll', 'gender', 'cgpa'], dtype='object')

# %% [markdown]
# ### merging

# %%
pd.merge(df1, newdf, on = 'roll')
# Out:
#    roll     name class  marks  age gender   cgpa
# 0   101     anil    TE  56.77   22      m  7.177
# 1   102     amit    TE  59.77   21      m  7.477
# 2   103   aniket    BE  76.88   19      m  9.188
# 3   104  ajinkya    TE  69.66   20      m  8.466
# 4   105     asha    TE  63.28   20      f  7.828
# 5   106   ayesha    BE  49.55   20      f  6.455
# 6   107     amar    BE  65.34   19      m  8.034
# 7   108    amita    BE  68.33   23      f  8.333
# 8   109     amol    TE  56.75   20      m  7.175
# 9   110    anmol    BE  78.66   21      m  9.366

# %%
newdf = pd.read_csv('student5.csv')
newdf
# Out:
#    roll     name class  marks  age
# 0     1   surbhi    TE  67.44   23
# 1     2    sujay    TE  74.12   22
# 2     3  subhash    BE  82.44   21
# 3     4   sachin    TE  59.33   21
# 4     5  shalini    TE  63.45   20

# %%
# concat

pd.concat([df1, newdf], ignore_index= True)
# Out:
#     roll     name class  marks  age
# 0    101     anil    TE  56.77   22
# 1    102     amit    TE  59.77   21
# 2    103   aniket    BE  76.88   19
# 3    104  ajinkya    TE  69.66   20
# 4    105     asha    TE  63.28   20
# 5    106   ayesha    BE  49.55   20
# 6    107     amar    BE  65.34   19
# 7    108    amita    BE  68.33   23
# 8    109     amol    TE  56.75   20
# 9    110    anmol    BE  78.66   21
# 10     1   surbhi    TE  67.44   23
# 11     2    sujay    TE  74.12   22
# 12     3  subhash    BE  82.44   21
# 13     4   sachin    TE  59.33   21
# 14     5  shalini    TE  63.45   20

# %%
# Out:
# 102

# %% [markdown]
# ### Boolean filtering

# %%
marks = df1['marks'] > 60

# %%
df1[marks]
# Out:
#    roll     name class  marks  age
# 2   103   aniket    BE  76.88   19
# 3   104  ajinkya    TE  69.66   20
# 4   105     asha    TE  63.28   20
# 6   107     amar    BE  65.34   19
# 7   108    amita    BE  68.33   23
# 9   110    anmol    BE  78.66   21

# %%
df1[df1['marks'] > 60]
# Out:
#    roll     name class  marks  age
# 2   103   aniket    BE  76.88   19
# 3   104  ajinkya    TE  69.66   20
# 4   105     asha    TE  63.28   20
# 6   107     amar    BE  65.34   19
# 7   108    amita    BE  68.33   23
# 9   110    anmol    BE  78.66   21

# %%
df1[(df1['marks'] > 60) & (df1['class'] == 'TE')]
# Out:
#    roll     name class  marks  age
# 3   104  ajinkya    TE  69.66   20
# 4   105     asha    TE  63.28   20

# %%
df1[df1['name'].str.startswith('am')]
# Out:
#    roll   name class  marks  age
# 1   102   amit    TE  59.77   21
# 6   107   amar    BE  65.34   19
# 7   108  amita    BE  68.33   23
# 8   109   amol    TE  56.75   20

# %%
df1[(df1['marks'] > 60) & (df1['class'] == 'BE')]
# Out:
#    roll    name class  marks  age
# 2   103  aniket    BE  76.88   19
# 6   107    amar    BE  65.34   19
# 7   108   amita    BE  68.33   23
# 9   110   anmol    BE  78.66   21

# %% [markdown]
# ### export

# %%
x = df1[(df1['marks'] > 60) & (df1['class'] == 'BE')]
x
# Out:
#    roll    name class  marks  age
# 2   103  aniket    BE  76.88   19
# 6   107    amar    BE  65.34   19
# 7   108   amita    BE  68.33   23
# 9   110   anmol    BE  78.66   21

# %%
x.to_csv('output.csv',index = False)

# %%
y = pd.read_csv('output.csv')
y
# Out:
#    roll    name class  marks  age
# 0   103  aniket    BE  76.88   19
# 1   107    amar    BE  65.34   19
# 2   108   amita    BE  68.33   23
# 3   110   anmol    BE  78.66   21
